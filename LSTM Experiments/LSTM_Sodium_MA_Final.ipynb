# %%
# %cd '/data/ztham/'
# Out:
# /data/ztham

# %%
# %pip install pandas
# %pip install seaborn
# %pip install numpy
# %pip install tensorflow
# %pip install scikit-learn

# %%
#imports
import pandas as pd
import math
from datetime import datetime, timedelta
import seaborn as sns
import matplotlib.pyplot as plt
from collections.abc import Collection
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.models import Sequential
from keras.layers import RepeatVector
from keras.layers import TimeDistributed, Input
from keras.models import Model
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.layers import LSTM, Dropout, RepeatVector, TimeDistributed, Dense, Bidirectional
from tensorflow.keras.regularizers import l2
import tensorflow as tf

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv("sodium.csv")
df1 = df.copy()
print(df.shape)
# Out:
# (64691, 2)

# %%
df.head()
# Out:
#    Day  Result
# 0    1   142.0
# 1    1   139.0
# 2    1   131.0
# 3    1   132.0
# 4    2   139.0

# %% [markdown]
# #Splitting of Dataset

# %%
# df will undergo bias simulation, df1 will retain the original data
df['Result'] = df.groupby('Day', group_keys=False)['Result'].apply(simulation)
df.loc[:, 'Result'] = df.groupby('Day')['Result'].transform(simulation)

# Split into training and testing
# 80% training, 20% testing
mid_day = math.ceil(df['Day'].max()*0.8)
train = df1[df1['Day'] <= mid_day] # Non-anomalous, using df1
# test = df[df['Day'] > mid_day] # Some anomalies is found, using df // no test set here since is just training
print(mid_day, train.shape)

# %% [markdown]
# # UNSUPERVISED LEARNING - LSTM

# %% [markdown]
# ### Normalise through scaling

# %%
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train[['Result']])
train_scaled_df = pd.concat([train['Day'], pd.DataFrame(scaled_train, columns=['Result'], index=train.index)], axis=1)

print(train_scaled_df.shape)
# Out:
# (51164, 2) (13527, 2)

# %% [markdown]
# ### Moving Average to smooth out the dataset

# %%
# Moving Average
MA_WINDOW_SIZE = 50 # Increase the value if needed smoother trend

ma_train = train_scaled_df['Result'].rolling(window=MA_WINDOW_SIZE).mean()
ma_train = pd.DataFrame(ma_train, columns=['Result'])

ma_train_df = pd.DataFrame(ma_train, columns=['Result'])
ma_train_df['Day'] = train['Day'].values[:len(ma_train_df)]
ma_train_df = ma_train_df[['Day', 'Result']]


fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Plot for the first subplot (train set)
axs[0].plot(train_scaled_df['Result'], label='Original', color='blue')
axs[0].plot(ma_train, label='Moving Average (Train Set)', color='orange')
axs[0].set_title('Original Result vs Moving Average (Train Set)')
axs[0].set_xlabel('Index')
axs[0].set_ylabel('Result')
axs[0].legend()
axs[0].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create sequences for LSTM (Make it 3D)

# %%
TIMESTEP = 70

def create_sequences_with_null(data, sequence_length):
    sequences = []
    # Find the index where 'Result' is not null
    start_index = np.argmax(~np.isnan(data['Result']))

    # Initialize variables to track the current day and the start index of the current day
    current_day = data['Day'].iloc[start_index]
    current_day_start = start_index

    for i in range(start_index, len(data) - sequence_length + 1):
        # Check if any NaN values are present in the sequence
        if data['Result'].iloc[i:i+sequence_length].isnull().any():
            # Move to the next day
            current_day += 1
            current_day_start = data[data['Day'] == current_day].index[0]
            continue  # Skip sequences with NaN values

        # Check if the sequence spans across multiple days
        if data['Day'].iloc[i] != current_day:
            # Move to the next day
            current_day += 1
            current_day_start = data[data['Day'] == current_day].index[0]
            continue  # Skip sequences spanning multiple days

        sequence = data['Result'].iloc[i:i+sequence_length]  # Select only the 'Result' column
        sequences.append(sequence)

    return np.array(sequences)

# Create sequences from the moving average data for both train
# Note: here we use ma_train and not ma_train_df (ma_train_df contains day, result. we create sequences only with Result)
sequences_ma_train = create_sequences_with_null(ma_train_df, TIMESTEP)
sequences_ma_train = sequences_ma_train.reshape(-1, TIMESTEP, 1)

print(sequences_ma_train.shape)
# Out:
# (50975, 70, 1) (13392, 70, 1)

# %% [markdown]
# ### Model Training

# %%
# Define the input shape
input_shape = (TIMESTEP, 1)

# Define the encoder layers
encoder_inputs = Input(shape=input_shape)
encoder = LSTM(units=64, return_sequences=True)(encoder_inputs)
encoder = Dropout(0.2)(encoder)  # Add dropout layer
encoder = LSTM(units=32, return_sequences=True)(encoder)
encoder = Dropout(0.2)(encoder)  # Add dropout layer
encoder = LSTM(units=16, return_sequences=False)(encoder)

# Define the decoder layers
decoder = RepeatVector(TIMESTEP)(encoder)
decoder = LSTM(units=16, return_sequences=True)(decoder)
decoder = Dropout(0.2)(decoder)  # Add dropout layer
decoder = LSTM(units=32, return_sequences=True)(decoder)
decoder = Dropout(0.2)(decoder)  # Add dropout layer
decoder_outputs = TimeDistributed(Dense(units=1))(decoder)

# Combine encoder and decoder into an autoencoder model
model = Model(inputs=encoder_inputs, outputs=decoder_outputs)

# Compile the autoencoder model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse')

# Print the model summary
model.summary()
# Out:
# 2024-05-12 04:33:20.214821: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.220974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.221157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.221623: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-12 04:33:20.223169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.223355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.223490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.737126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.737348: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.737497: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-12 04:33:20.737649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14738 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:0b:00.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 70, 1)]           0
#
#  lstm (LSTM)                 (None, 70, 64)            16896
#
#  dropout (Dropout)           (None, 70, 64)            0
#
#  lstm_1 (LSTM)               (None, 70, 32)            12416
#
#  dropout_1 (Dropout)         (None, 70, 32)            0
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  repeat_vector (RepeatVector  (None, 70, 16)           0
#  )
#
#  lstm_3 (LSTM)               (None, 70, 16)            2112
#
#  dropout_2 (Dropout)         (None, 70, 16)            0
#
#  lstm_4 (LSTM)               (None, 70, 32)            6272
#
#  dropout_3 (Dropout)         (None, 70, 32)            0
#
#  time_distributed (TimeDistr  (None, 70, 1)            33
#  ibuted)
#
# =================================================================
# Total params: 40,865
# Trainable params: 40,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(sequences_ma_train, sequences_ma_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1, callbacks = [early_stopping])
# Out:
# Epoch 1/100
# 2024-05-12 04:33:28.240039: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 1275/1275 [==============================] - 28s 16ms/step - loss: 0.0048 - val_loss: 3.1991e-04
# Epoch 2/100
# 1275/1275 [==============================] - 19s 15ms/step - loss: 0.0010 - val_loss: 4.4879e-04
# Epoch 3/100
# 1275/1275 [==============================] - 19s 15ms/step - loss: 3.9838e-04 - val_loss: 4.1259e-04
# Epoch 4/100
# 1275/1275 [==============================] - 19s 15ms/step - loss: 2.0834e-04 - val_loss: 5.2603e-04
# Epoch 5/100
# 1275/1275 [==============================] - 19s 15ms/step - loss: 1.8282e-04 - val_loss: 3.8188e-04
# Epoch 6/100
# 1275/1275 [==============================] - 19s 15ms/step - loss: 1.8048e-04 - val_loss: 4.1277e-04

# %%
# Get training and validation loss history
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
model.save('LSTM_Sodium_MA_2.h5') # Save model
